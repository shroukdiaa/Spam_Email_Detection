# %% [markdown]
# <a href="https://colab.research.google.com/github/shroukdiaa/Spam_Email_Detection/blob/main/Spam_Email_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("/content/spam.csv")

df.head()

# %%
df['Message'] = df['Message'].str.lower()
df.head()

# %% [markdown]
# # features

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(df['Message'])
y = df['Category']

# %% [markdown]
# # Train Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

model = MultinomialNB()
model.fit(X_train,y_train)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
print(classification_report(y_test,y_pred))

# %% [markdown]
# # Prediction

# %%
email = ["Congratulations you won free money"]

email_vec = vectorizer.transform(email)

prediction = model.predict(email_vec)

print(prediction)

# %%
import joblib

joblib.dump(model,"spam_model.pkl")
